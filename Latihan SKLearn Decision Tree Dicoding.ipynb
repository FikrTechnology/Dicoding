# %% [markdown]
# **Tujuan**
#
# pada latihan ini, kita akan menggunakan data yang lebih kompleks dari sebuah numpy array. Untuk coding practice kali ini kita akan memakai dataset Iris, salah satu dataset paling populer yang dipakai belajar ML.
#
# **Tahapan Latihan**
#
# Dataset Iris terdiri dari 4 atribut yaitu panjang sepal, lebar sepal, panjang petal, lebar petal. Terdapat 3 kelas target pada dataset ini. Data ini di pakai untuk masalah klasifikasi, dimana kita bisa memprediksi spesies dari sebuah bunga berdasarkan atribut-atribut yang di berikan
#
# Tahapan yang ada pada latihan ini antara lain:
#
# 1. Ubah dataset ke dalam dataframe.
# 2. Hapus kolom 'ID' pada dataframe dan pisahkan antara atribut dan label.
# 3. Buat dan latih model Decision Tree.
# 4. Lakukan prediksi dengan model yang telah dilatih.
# 5. Visualisasi model Decision Tree yang telah di latih.

# %%
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.tree import export_graphviz

# %%
os.listdir('/content/sample_data')
# Out:
# ['README.md',
#  'anscombe.json',
#  'Iris.csv',
#  'mnist_train_small.csv',
#  'california_housing_test.csv',
#  'california_housing_train.csv',
#  'mnist_test.csv']

# %%
iris = pd.read_csv('/content/sample_data/Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id', axis=1, inplace=True)

# %%
X = iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = iris['Species']

# %%
# Membuat Decision Tree
tree_model = DecisionTreeClassifier()

# Melakukan pekatihan model terhadap data
tree_model.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# Tree_model.predict([['SepalLengthCm', SepalWidthCm, PetalLengthCm, PetalWidthCm]])
tree_model.predict([[6.2, 3.4, 5.4, 2.3]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
export_graphviz(
    tree_model,
    out_file = 'iris_tree.dot',
    feature_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
    class_names = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
    rounded = True,
    filled = True
)
