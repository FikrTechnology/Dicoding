# %% [markdown]
# **Tujuan**
#
# pada codelab ini kita akan belajar membagi datset menggunakan fungsi Train Test Split dari SKLearn.
#
# **Tahapan Latihan**
#
# untuk latihan membagi dataset terdiri dari tahapan-tahapan sebagai berikut:
#
# 1. Persiapkan dataset ke dalam Notebook
# 2. Import Library SKLearn.
# 3. Buat variable untuk menampung data training dan data Testing
# 4. Panggil fungsi train_test_split()

# %%
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

# %%
x = iris.data
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(y)
# Out:
# 150
