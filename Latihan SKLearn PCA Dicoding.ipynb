# %% [markdown]
# **Tujuan**
#
# Pada latihan ini kita akan mencoba mengimplementasi PCA dengan library SKLearn.
#
# **Tahapan Latihan**
#
# Tahapan pada latihan ini sebagai berikut:
#
# 1. Bagi dataset.
# 2. Latih model tanpa PCA.
# 3. Latih model dengan PCA.
# 4. Evaluasi hasil kedua model.

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
iris = datasets.load_iris()
atribut = iris.data
label = iris.target

# Bagi dataset menjadi train set dan test set
X_train, X_test, y_train, y_test = train_test_split(
    atribut, label, test_size=0.2
)

# %%
# Menggunakan model Decision tree dan menghitung berapa akurasi tanpa PCA
from sklearn import tree

decision_tree = tree.DecisionTreeClassifier()

model_pertama = decision_tree.fit(X_train, y_train)
model_pertama.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
# Menggunakan PCA dan menghitung variance dari setiap atribut.
# membuat objek PCA dengan 4 principal component
pca = PCA(n_components=4)

# mengaplikasikan PCA pada dataset
pca_attributes = pca.fit_transform(X_train)

# melihat variance dari setiap atribut
pca.explained_variance_ratio_
# Out:
# array([0.92463689, 0.05450985, 0.01605558, 0.00479767])

# %%
pca =PCA(n_components = 2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.fit_transform(X_test)

# %%
# Menguji akurasi dari classifier setelah menggunakan PCA.
model2 = decision_tree.fit(X_train_pca, y_train)
model2.score(X_test_pca, y_test)
# Out:
# 0.9666666666666667
